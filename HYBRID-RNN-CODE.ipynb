# %%
# !pip install yfinance numpy pandas matplotlib scikit-learn tensorflow
import yfinance as yf
import pandas as pd
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from tensorflow.keras.models import load_model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Bidirectional, Dense


# Set seeds for reproducibility
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

cryptos = ['BTC-USD', 'ETH-USD', 'LTC-USD']
start_date = '2019-01-01'
end_date = '2024-01-01'

crypto_data = {}

for ticker in cryptos:
    crypto_data[ticker] = yf.download(ticker, start=start_date, end=end_date)
    
    
    ### BTC
    

btc_data = crypto_data['BTC-USD']
btc_data.fillna(method='ffill', inplace=True)

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data_btc = scaler.fit_transform(btc_data[['Open', 'High', 'Low', 'Close', 'Adj Close']])

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        X.append(a)
        Y.append(dataset[i + look_back, -1])
    return np.array(X), np.array(Y)

look_back = 60
X_btc, Y_btc = create_dataset(scaled_data_btc, look_back)
X_btc = np.reshape(X_btc, (X_btc.shape[0], look_back, X_btc.shape[2]))

split_percent = 0.80
split = int(split_percent * len(X_btc))

X_train_btc = X_btc[:split]
Y_train_btc = Y_btc[:split]
X_test_btc = X_btc[split:]
Y_test_btc = Y_btc[split:]


lstm_gru_model = Sequential()
lstm_gru_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_btc.shape[1], X_train_btc.shape[2])))
lstm_gru_model.add(GRU(units=100))
lstm_gru_model.add(Dense(1))
lstm_gru_model.compile(optimizer='adam', loss='mean_squared_error')

gru_bilstm_model = Sequential()
gru_bilstm_model.add(GRU(units=100, return_sequences=True, input_shape=(X_train_btc.shape[1], X_train_btc.shape[2])))
gru_bilstm_model.add(Bidirectional(LSTM(units=100)))
gru_bilstm_model.add(Dense(1))
gru_bilstm_model.compile(optimizer='adam', loss='mean_squared_error')

lstm_bilstm_model = Sequential()
lstm_bilstm_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_btc.shape[1], X_train_btc.shape[2])))
lstm_bilstm_model.add(Bidirectional(LSTM(units=100)))
lstm_bilstm_model.add(Dense(1))
lstm_bilstm_model.compile(optimizer='adam', loss='mean_squared_error')

lstm_gru_history = lstm_gru_model.fit(X_train_btc, Y_train_btc, epochs=100, batch_size=32, validation_data=(X_test_btc, Y_test_btc), verbose=1)
gru_bilstm_history = gru_bilstm_model.fit(X_train_btc, Y_train_btc, epochs=100, batch_size=32, validation_data=(X_test_btc, Y_test_btc), verbose=1)
lstm_bilstm_history = lstm_bilstm_model.fit(X_train_btc, Y_train_btc, epochs=100, batch_size=32, validation_data=(X_test_btc, Y_test_btc), verbose=1)
lstm_gru_scores = lstm_gru_model.evaluate(X_test_btc, Y_test_btc, verbose=0)
gru_bilstm_scores = gru_bilstm_model.evaluate(X_test_btc, Y_test_btc, verbose=0)
lstm_bilstm_scores = lstm_bilstm_model.evaluate(X_test_btc, Y_test_btc, verbose=0)

print('LSTM-GRU Test loss:', lstm_gru_scores)
print('GRU-BiLSTM Test loss:', gru_bilstm_scores)
print('LSTM-BiLSTM Test loss:', lstm_bilstm_scores)

plt.figure(figsize=(18, 5))

# LSTM-GRU
plt.subplot(1, 3, 1)
plt.plot(lstm_gru_history.history['loss'], label='LSTM-GRU training Loss')
plt.plot(lstm_gru_history.history['val_loss'], label='LSTM-GRU Validation Loss')
plt.title('LSTM-GRU Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# GRU-BiLSTM
plt.subplot(1, 3, 2)
plt.plot(gru_bilstm_history.history['loss'], label='GRU-BiLSTM training Loss')
plt.plot(gru_bilstm_history.history['val_loss'], label='GRU-BiLSTM Validation Loss')
plt.title('GRU-BiLSTM Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# LSTM-BiLSTM
plt.subplot(1, 3, 3)
plt.plot(lstm_bilstm_history.history['loss'], label='LSTM-BiLSTM training Loss')
plt.plot(lstm_bilstm_history.history['val_loss'], label='LSTM-BiLSTM Validation Loss')
plt.title('LSTM-BiLSTM Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.savefig('BTC-hybrid-models-loss.png')
plt.show()

lstm_gru_predictions = lstm_gru_model.predict(X_test_btc)
gru_bilstm_predictions = gru_bilstm_model.predict(X_test_btc)
lstm_bilstm_predictions = lstm_bilstm_model.predict(X_test_btc)


# Generate date range for x-axis
date_range = pd.date_range(start=start_date, end=end_date, periods=len(Y_test_btc))

# Plot actual vs. predicted prices for the LSTM-GRU model
plt.figure(figsize=(10, 6))
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(Y_test_btc), scaled_data_btc.shape[1]-1)), Y_test_btc.reshape(-1, 1)), axis=1))[:, -1], label='Actual Prices', color='darkorange')
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(lstm_gru_predictions), scaled_data_btc.shape[1]-1)), lstm_gru_predictions), axis=1))[:, -1], label='Predicted Prices', color='limegreen')
plt.title('For BTC Comparison of Actual and LSTM-GRU Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks to each year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format date to only show years
plt.legend()
plt.grid(True)

# Save the plot to the current directory
plt.savefig('btc-lstm-gru.png')
plt.show()

# Plot actual vs. predicted prices for the GRU-BiLSTM model
plt.figure(figsize=(10, 6))
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(Y_test_btc), scaled_data_btc.shape[1]-1)), Y_test_btc.reshape(-1, 1)), axis=1))[:, -1], label='Actual Prices', color='darkorange')
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(gru_bilstm_predictions), scaled_data_btc.shape[1]-1)), gru_bilstm_predictions), axis=1))[:, -1], label='Predicted Prices', color='limegreen')
plt.title('For BTC Comparison of Actual and GRU-BiLSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks to each year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format date to only show years
plt.legend()
plt.grid(True)

# Save the plot to the current directory
plt.savefig('btc-gru-bilstm.png')
plt.show()

# Plot actual vs. predicted prices for the LSTM-BiLSTM model
plt.figure(figsize=(10, 6))
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(Y_test_btc), scaled_data_btc.shape[1]-1)), Y_test_btc.reshape(-1, 1)), axis=1))[:, -1], label='Actual Prices', color='darkorange')
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(lstm_bilstm_predictions), scaled_data_btc.shape[1]-1)), lstm_bilstm_predictions), axis=1))[:, -1], label='Predicted Prices', color='limegreen')
plt.title('For BTC Comparison of Actual and LSTM-BiLSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks to each year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format date to only show years
plt.legend()
plt.grid(True)

# Save the plot to the current directory
plt.savefig('btc-lstm-bilstm.png')
plt.show()

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Make predictions
lstm_gru_predictions = lstm_gru_model.predict(X_test_btc)
gru_bilstm_predictions = gru_bilstm_model.predict(X_test_btc)
lstm_bilstm_predictions = lstm_bilstm_model.predict(X_test_btc)


# Calculate MSE and MAE for LSTM-GRU
lstm_gru_mse = mean_squared_error(Y_test_btc, lstm_gru_predictions)
lstm_gru_mae = mean_absolute_error(Y_test_btc, lstm_gru_predictions)

# Calculate MSE and MAE for GRU-BiLSTM
gru_bilstm_mse = mean_squared_error(Y_test_btc, gru_bilstm_predictions)
gru_bilstm_mae = mean_absolute_error(Y_test_btc, gru_bilstm_predictions)

# Calculate MSE and MAE for LSTM-BiLSTM
lstm_bilstm_mse = mean_squared_error(Y_test_btc, lstm_bilstm_predictions)
lstm_bilstm_mae = mean_absolute_error(Y_test_btc, lstm_bilstm_predictions)

# Print the scores
print(f'LSTM-GRU MSE: {lstm_gru_mse}, MAE: {lstm_gru_mae}')
print(f'GRU-BiLSTM MSE: {gru_bilstm_mse}, MAE: {gru_bilstm_mae}')
print(f'LSTM-BiLSTM MSE: {lstm_bilstm_mse}, MAE: {lstm_bilstm_mae}')

def calculate_rmse(actuals, predictions):
    """
    Calculate Root Mean Squared Error
    """
    mse = np.mean((actuals - predictions) ** 2)
    rmse = np.sqrt(mse)
    return rmse

def calculate_mape(actuals, predictions):
    """
    Calculate Mean Absolute Percentage Error
    """
    mape = np.mean(np.abs((actuals - predictions) / actuals)) * 100
    return mape


# Calculate RMSE and MAPE
lstm_gru_rmse = calculate_rmse(Y_test_btc, lstm_gru_predictions.flatten())
gru_bilstm_rmse = calculate_rmse(Y_test_btc, gru_bilstm_predictions.flatten())
lstm_bilstm_rmse = calculate_rmse(Y_test_btc, lstm_bilstm_predictions.flatten())

lstm_gru_mape = calculate_mape(Y_test_btc, lstm_gru_predictions.flatten())
gru_bilstm_mape = calculate_mape(Y_test_btc, gru_bilstm_predictions.flatten())
lstm_bilstm_mape = calculate_mape(Y_test_btc, lstm_bilstm_predictions.flatten())

print(f'LSTM-GRU RMSE: {lstm_gru_rmse:.3f}, MAPE: {lstm_gru_mape:.2f}%')
print(f'GRU-BiLSTM RMSE: {gru_bilstm_rmse:.3f}, MAPE: {gru_bilstm_mape:.2f}%')
print(f'LSTM-BiLSTM RMSE: {lstm_bilstm_rmse:.3f}, MAPE: {lstm_bilstm_mape:.2f}%')


### ETH

eth_data = crypto_data['ETH-USD']
eth_data.fillna(method='ffill', inplace=True)

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data_eth = scaler.fit_transform(eth_data[['Open', 'High', 'Low', 'Close', 'Adj Close']])

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        X.append(a)
        Y.append(dataset[i + look_back, -1])
    return np.array(X), np.array(Y)

look_back = 60
X_eth, Y_eth = create_dataset(scaled_data_eth, look_back)
X_eth = np.reshape(X_eth, (X_eth.shape[0], look_back, X_eth.shape[2]))

split_percent = 0.80
split = int(split_percent * len(X_eth))

X_train_eth = X_eth[:split]
Y_train_eth = Y_eth[:split]
X_test_eth = X_eth[split:]
Y_test_eth = Y_eth[split:]

lstm_gru_model = Sequential()
lstm_gru_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_eth.shape[1], X_train_eth.shape[2])))
lstm_gru_model.add(GRU(units=100))
lstm_gru_model.add(Dense(1))
lstm_gru_model.compile(optimizer='adam', loss='mean_squared_error')

gru_bilstm_model = Sequential()
gru_bilstm_model.add(GRU(units=100, return_sequences=True, input_shape=(X_train_eth.shape[1], X_train_eth.shape[2])))
gru_bilstm_model.add(Bidirectional(LSTM(units=100)))
gru_bilstm_model.add(Dense(1))
gru_bilstm_model.compile(optimizer='adam', loss='mean_squared_error')

lstm_bilstm_model = Sequential()
lstm_bilstm_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_eth.shape[1], X_train_eth.shape[2])))
lstm_bilstm_model.add(Bidirectional(LSTM(units=100)))
lstm_bilstm_model.add(Dense(1))
lstm_bilstm_model.compile(optimizer='adam', loss='mean_squared_error')

lstm_gru_history = lstm_gru_model.fit(X_train_eth, Y_train_eth, epochs=100, batch_size=32, validation_data=(X_test_eth, Y_test_eth), verbose=1)
gru_bilstm_history = gru_bilstm_model.fit(X_train_eth, Y_train_eth, epochs=100, batch_size=32, validation_data=(X_test_eth, Y_test_eth), verbose=1)
lstm_bilstm_history = lstm_bilstm_model.fit(X_train_eth, Y_train_eth, epochs=100, batch_size=32, validation_data=(X_test_eth, Y_test_eth), verbose=1)
lstm_gru_scores = lstm_gru_model.evaluate(X_test_eth, Y_test_eth, verbose=0)
gru_bilstm_scores = gru_bilstm_model.evaluate(X_test_eth, Y_test_eth, verbose=0)
lstm_bilstm_scores = lstm_bilstm_model.evaluate(X_test_eth, Y_test_eth, verbose=0)

print('LSTM-GRU Test loss:', lstm_gru_scores)
print('GRU-BiLSTM Test loss:', gru_bilstm_scores)
print('LSTM-BiLSTM Test loss:', lstm_bilstm_scores)
plt.figure(figsize=(18, 5))

# LSTM-GRU
plt.subplot(1, 3, 1)
plt.plot(lstm_gru_history.history['loss'], label='LSTM-GRU training Loss')
plt.plot(lstm_gru_history.history['val_loss'], label='LSTM-GRU Validation Loss')
plt.title('LSTM-GRU Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# GRU-BiLSTM
plt.subplot(1, 3, 2)
plt.plot(gru_bilstm_history.history['loss'], label='GRU-BiLSTM training Loss')
plt.plot(gru_bilstm_history.history['val_loss'], label='GRU-BiLSTM Validation Loss')
plt.title('GRU-BiLSTM Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# LSTM-BiLSTM
plt.subplot(1, 3, 3)
plt.plot(lstm_bilstm_history.history['loss'], label='LSTM-BiLSTM training Loss')
plt.plot(lstm_bilstm_history.history['val_loss'], label='LSTM-BiLSTM Validation Loss')
plt.title('LSTM-BiLSTM Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.savefig('ETH-hybrid-models-loss.png')
plt.show()

lstm_gru_predictions = lstm_gru_model.predict(X_test_eth)
gru_bilstm_predictions = gru_bilstm_model.predict(X_test_eth)
lstm_bilstm_predictions = lstm_bilstm_model.predict(X_test_eth)

# Generate date range for x-axis
date_range = pd.date_range(start=start_date, end=end_date, periods=len(Y_test_eth))

# Plot actual vs. predicted prices for the LSTM-GRU model
plt.figure(figsize=(10, 6))
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(Y_test_eth), scaled_data_eth.shape[1]-1)), Y_test_eth.reshape(-1, 1)), axis=1))[:, -1], label='Actual Prices', color='crimson')
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(lstm_gru_predictions), scaled_data_eth.shape[1]-1)), lstm_gru_predictions), axis=1))[:, -1], label='Predicted Prices', color='cyan')
plt.title('For ETH Comparison of Actual and LSTM-GRU Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks to each year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format date to only show years
plt.legend()
plt.grid(True)

# Save the plot to the current directory
plt.savefig('eth-lstm-gru.png')
plt.show()

# Plot actual vs. predicted prices for the GRU-BiLSTM model
plt.figure(figsize=(10, 6))
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(Y_test_eth), scaled_data_eth.shape[1]-1)), Y_test_eth.reshape(-1, 1)), axis=1))[:, -1], label='Actual Prices', color='crimson')
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(gru_bilstm_predictions), scaled_data_eth.shape[1]-1)), gru_bilstm_predictions), axis=1))[:, -1], label='Predicted Prices', color='cyan')
plt.title('For ETH Comparison of Actual and GRU-BiLSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks to each year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format date to only show years
plt.legend()
plt.grid(True)

# Save the plot to the current directory
plt.savefig('eth-gru-bilstm.png')
plt.show()

# Plot actual vs. predicted prices for the LSTM-BiLSTM model
plt.figure(figsize=(10, 6))
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(Y_test_eth), scaled_data_eth.shape[1]-1)), Y_test_eth.reshape(-1, 1)), axis=1))[:, -1], label='Actual Prices', color='crimson')
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(lstm_bilstm_predictions), scaled_data_eth.shape[1]-1)), lstm_bilstm_predictions), axis=1))[:, -1], label='Predicted Prices', color='cyan')
plt.title('For ETH Comparison of Actual and LSTM-BiLSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks to each year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format date to only show years
plt.legend()
plt.grid(True)

# Save the plot to the current directory
plt.savefig('eth-lstm-bilstm.png')
plt.show()

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Make predictions
lstm_gru_predictions = lstm_gru_model.predict(X_test_eth)
gru_bilstm_predictions = gru_bilstm_model.predict(X_test_eth)
lstm_bilstm_predictions = lstm_bilstm_model.predict(X_test_eth)

# Calculate MSE and MAE for LSTM-GRU
lstm_gru_mse = mean_squared_error(Y_test_eth, lstm_gru_predictions)
lstm_gru_mae = mean_absolute_error(Y_test_eth, lstm_gru_predictions)

# Calculate MSE and MAE for GRU-BiLSTM
gru_bilstm_mse = mean_squared_error(Y_test_eth, gru_bilstm_predictions)
gru_bilstm_mae = mean_absolute_error(Y_test_eth, gru_bilstm_predictions)

# Calculate MSE and MAE for LSTM-BiLSTM
lstm_bilstm_mse = mean_squared_error(Y_test_eth, lstm_bilstm_predictions)
lstm_bilstm_mae = mean_absolute_error(Y_test_eth, lstm_bilstm_predictions)

# Print the scores
print(f'LSTM-GRU MSE: {lstm_gru_mse}, MAE: {lstm_gru_mae}')
print(f'GRU-BiLSTM MSE: {gru_bilstm_mse}, MAE: {gru_bilstm_mae}')
print(f'LSTM-BiLSTM MSE: {lstm_bilstm_mse}, MAE: {lstm_bilstm_mae}')

def calculate_rmse(actuals, predictions):
    """
    Calculate Root Mean Squared Error
    """
    mse = np.mean((actuals - predictions) ** 2)
    rmse = np.sqrt(mse)
    return rmse

def calculate_mape(actuals, predictions):
    """
    Calculate Mean Absolute Percentage Error
    """
    mape = np.mean(np.abs((actuals - predictions) / actuals)) * 100
    return mape


# Calculate RMSE and MAPE
lstm_gru_rmse = calculate_rmse(Y_test_eth, lstm_gru_predictions.flatten())
gru_bilstm_rmse = calculate_rmse(Y_test_eth, gru_bilstm_predictions.flatten())
lstm_bilstm_rmse = calculate_rmse(Y_test_eth, lstm_bilstm_predictions.flatten())

lstm_gru_mape = calculate_mape(Y_test_eth, lstm_gru_predictions.flatten())
gru_bilstm_mape = calculate_mape(Y_test_eth, gru_bilstm_predictions.flatten())
lstm_bilstm_mape = calculate_mape(Y_test_eth, lstm_bilstm_predictions.flatten())

print(f'LSTM-GRU RMSE: {lstm_gru_rmse:.3f}, MAPE: {lstm_gru_mape:.2f}%')
print(f'GRU-BiLSTM RMSE: {gru_bilstm_rmse:.3f}, MAPE: {gru_bilstm_mape:.2f}%')
print(f'LSTM-BiLSTM RMSE: {lstm_bilstm_rmse:.3f}, MAPE: {lstm_bilstm_mape:.2f}%')

###LTC


ltc_data = crypto_data['LTC-USD']
ltc_data.fillna(method='ffill', inplace=True)

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data_ltc = scaler.fit_transform(ltc_data[['Open', 'High', 'Low', 'Close', 'Adj Close']])

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        X.append(a)
        Y.append(dataset[i + look_back, -1])
    return np.array(X), np.array(Y)

look_back = 60
X_ltc, Y_ltc = create_dataset(scaled_data_ltc, look_back)
X_ltc = np.reshape(X_ltc, (X_ltc.shape[0], look_back, X_ltc.shape[2]))

split_percent = 0.80
split = int(split_percent * len(X_ltc))

X_train_ltc = X_ltc[:split]
Y_train_ltc = Y_ltc[:split]
X_test_ltc = X_ltc[split:]
Y_test_ltc = Y_ltc[split:]

lstm_gru_model = Sequential()
lstm_gru_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_ltc.shape[1], X_train_ltc.shape[2])))
lstm_gru_model.add(GRU(units=100))
lstm_gru_model.add(Dense(1))
lstm_gru_model.compile(optimizer='adam', loss='mean_squared_error')

gru_bilstm_model = Sequential()
gru_bilstm_model.add(GRU(units=100, return_sequences=True, input_shape=(X_train_ltc.shape[1], X_train_ltc.shape[2])))
gru_bilstm_model.add(Bidirectional(LSTM(units=100)))
gru_bilstm_model.add(Dense(1))
gru_bilstm_model.compile(optimizer='adam', loss='mean_squared_error')

lstm_bilstm_model = Sequential()
lstm_bilstm_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_ltc.shape[1], X_train_ltc.shape[2])))
lstm_bilstm_model.add(Bidirectional(LSTM(units=100)))
lstm_bilstm_model.add(Dense(1))
lstm_bilstm_model.compile(optimizer='adam', loss='mean_squared_error')

lstm_gru_history = lstm_gru_model.fit(X_train_ltc, Y_train_ltc, epochs=100, batch_size=32, validation_data=(X_test_ltc, Y_test_ltc), verbose=1)
gru_bilstm_history = gru_bilstm_model.fit(X_train_ltc, Y_train_ltc, epochs=100, batch_size=32, validation_data=(X_test_ltc, Y_test_ltc), verbose=1)
lstm_bilstm_history = lstm_bilstm_model.fit(X_train_ltc, Y_train_ltc, epochs=100, batch_size=32, validation_data=(X_test_ltc, Y_test_ltc), verbose=1)
lstm_gru_scores = lstm_gru_model.evaluate(X_test_ltc, Y_test_ltc, verbose=0)
gru_bilstm_scores = gru_bilstm_model.evaluate(X_test_ltc, Y_test_ltc, verbose=0)
lstm_bilstm_scores = lstm_bilstm_model.evaluate(X_test_ltc, Y_test_ltc, verbose=0)

print('LSTM-GRU Test loss:', lstm_gru_scores)
print('GRU-BiLSTM Test loss:', gru_bilstm_scores)
print('LSTM-BiLSTM Test loss:', lstm_bilstm_scores)
plt.figure(figsize=(18, 5))

# LSTM-GRU
plt.subplot(1, 3, 1)
plt.plot(lstm_gru_history.history['loss'], label='LSTM-GRU training Loss')
plt.plot(lstm_gru_history.history['val_loss'], label='LSTM-GRU Validation Loss')
plt.title('LSTM-GRU Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# GRU-BiLSTM
plt.subplot(1, 3, 2)
plt.plot(gru_bilstm_history.history['loss'], label='GRU-BiLSTM training Loss')
plt.plot(gru_bilstm_history.history['val_loss'], label='GRU-BiLSTM Validation Loss')
plt.title('GRU-BiLSTM Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# LSTM-BiLSTM
plt.subplot(1, 3, 3)
plt.plot(lstm_bilstm_history.history['loss'], label='LSTM-BiLSTM training Loss')
plt.plot(lstm_bilstm_history.history['val_loss'], label='LSTM-BiLSTM Validation Loss')
plt.title('LSTM-BiLSTM Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.savefig('LTC-hybrid-models-loss.png')
plt.show()

lstm_gru_predictions = lstm_gru_model.predict(X_test_ltc)
gru_bilstm_predictions = gru_bilstm_model.predict(X_test_ltc)
lstm_bilstm_predictions = lstm_bilstm_model.predict(X_test_ltc)

# Generate date range for x-axis
date_range = pd.date_range(start=start_date, end=end_date, periods=len(Y_test_ltc))

# Plot actual vs. predicted prices for the LSTM-GRU model
plt.figure(figsize=(10, 6))
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(Y_test_ltc), scaled_data_ltc.shape[1]-1)), Y_test_ltc.reshape(-1, 1)), axis=1))[:, -1], label='Actual Prices', color='magenta')
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(lstm_gru_predictions), scaled_data_ltc.shape[1]-1)), lstm_gru_predictions), axis=1))[:, -1], label='Predicted Prices', color='deepskyblue')
plt.title('For LTC Comparison of Actual and LSTM-GRU Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks to each year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format date to only show years
plt.legend()
plt.grid(True)

# Save the plot to the current directory
plt.savefig('ltc-lstm-gru.png')
plt.show()

# Plot actual vs. predicted prices for the GRU-BiLSTM model
plt.figure(figsize=(10, 6))
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(Y_test_ltc), scaled_data_ltc.shape[1]-1)), Y_test_ltc.reshape(-1, 1)), axis=1))[:, -1], label='Actual Prices', color='magenta')
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(gru_bilstm_predictions), scaled_data_ltc.shape[1]-1)), gru_bilstm_predictions), axis=1))[:, -1], label='Predicted Prices', color='deepskyblue')
plt.title('For LTC Comparison of Actual and GRU-BiLSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks to each year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format date to only show years
plt.legend()
plt.grid(True)

# Save the plot to the current directory
plt.savefig('ltc-gru-bilstm.png')
plt.show()

# Plot actual vs. predicted prices for the LSTM-BiLSTM model
plt.figure(figsize=(10, 6))
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(Y_test_ltc), scaled_data_ltc.shape[1]-1)), Y_test_ltc.reshape(-1, 1)), axis=1))[:, -1], label='Actual Prices', color='magenta')
plt.plot(date_range, scaler.inverse_transform(np.concatenate((np.zeros((len(lstm_bilstm_predictions), scaled_data_ltc.shape[1]-1)), lstm_bilstm_predictions), axis=1))[:, -1], label='Predicted Prices', color='deepskyblue')
plt.title('For LTC Comparison of Actual and LSTM-BiLSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks to each year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format date to only show years
plt.legend()
plt.grid(True)

# Save the plot to the current directory
plt.savefig('ltc-lstm-bilstm.png')
plt.show()

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Make predictions
lstm_gru_predictions = lstm_gru_model.predict(X_test_ltc)
gru_bilstm_predictions = gru_bilstm_model.predict(X_test_ltc)
lstm_bilstm_predictions = lstm_bilstm_model.predict(X_test_ltc)

# Calculate MSE and MAE for LSTM-GRU
lstm_gru_mse = mean_squared_error(Y_test_ltc, lstm_gru_predictions)
lstm_gru_mae = mean_absolute_error(Y_test_ltc, lstm_gru_predictions)

# Calculate MSE and MAE for GRU-BiLSTM
gru_bilstm_mse = mean_squared_error(Y_test_ltc, gru_bilstm_predictions)
gru_bilstm_mae = mean_absolute_error(Y_test_ltc, gru_bilstm_predictions)

# Calculate MSE and MAE for LSTM-BiLSTM
lstm_bilstm_mse = mean_squared_error(Y_test_ltc, lstm_bilstm_predictions)
lstm_bilstm_mae = mean_absolute_error(Y_test_ltc, lstm_bilstm_predictions)

# Print the scores
print(f'LSTM-GRU MSE: {lstm_gru_mse}, MAE: {lstm_gru_mae}')
print(f'GRU-BiLSTM MSE: {gru_bilstm_mse}, MAE: {gru_bilstm_mae}')
print(f'LSTM-BiLSTM MSE: {lstm_bilstm_mse}, MAE: {lstm_bilstm_mae}')

def calculate_rmse(actuals, predictions):
    """
    Calculate Root Mean Squared Error
    """
    mse = np.mean((actuals - predictions) ** 2)
    rmse = np.sqrt(mse)
    return rmse

def calculate_mape(actuals, predictions):
    """
    Calculate Mean Absolute Percentage Error
    """
    mape = np.mean(np.abs((actuals - predictions) / actuals)) * 100
    return mape


# Calculate RMSE and MAPE
lstm_gru_rmse = calculate_rmse(Y_test_ltc, lstm_gru_predictions.flatten())
gru_bilstm_rmse = calculate_rmse(Y_test_ltc, gru_bilstm_predictions.flatten())
lstm_bilstm_rmse = calculate_rmse(Y_test_ltc, lstm_bilstm_predictions.flatten())

lstm_gru_mape = calculate_mape(Y_test_ltc, lstm_gru_predictions.flatten())
gru_bilstm_mape = calculate_mape(Y_test_ltc, gru_bilstm_predictions.flatten())
lstm_bilstm_mape = calculate_mape(Y_test_ltc, lstm_bilstm_predictions.flatten())

print(f'LSTM-GRU RMSE: {lstm_gru_rmse:.3f}, MAPE: {lstm_gru_mape:.2f}%')
print(f'GRU-BiLSTM RMSE: {gru_bilstm_rmse:.3f}, MAPE: {gru_bilstm_mape:.2f}%')
print(f'LSTM-BiLSTM RMSE: {lstm_bilstm_rmse:.3f}, MAPE: {lstm_bilstm_mape:.2f}%')
# Out:
# Requirement already satisfied: yfinance in c:\users\stumpa42\appdata\loca\lib\site-packages (0.2.37)
# Requirement already satisfied: numpy in c:\users\stumpa42\appdata\loca\lib\site-packages (1.24.3)
# Requirement already satisfied: pandas in c:\users\stumpa42\appdata\loca\lib\site-packages (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\stumpa42\appdata\loca\lib\site-packages (3.7.2)
# Requirement already satisfied: scikit-learn in c:\users\stumpa42\appdata\loca\lib\site-packages (1.3.0)
# Requirement already satisfied: tensorflow in c:\users\stumpa42\appdata\loca\lib\site-packages (2.16.1)
# Requirement already satisfied: requests>=2.31 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: webencodings in c:\users\stumpa42\appdata\loca\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.38.4)
# Requirement already satisfied: rich in c:\users\stumpa42\appdata\loca\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\stumpa42\appdata\loca\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\stumpa42\appdata\loca\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.0)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\stumpa42\AppData\Loca\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - loss: 0.0172 - val_loss: 4.0527e-04
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.0011 - val_loss: 5.7744e-04
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 9.3616e-04 - val_loss: 5.1445e-04
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 8.0693e-04 - val_loss: 3.5080e-04
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 7.2858e-04 - val_loss: 2.3476e-04
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 6.9746e-04 - val_loss: 2.2994e-04
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 6.6037e-04 - val_loss: 2.3971e-04
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 6.6218e-04 - val_loss: 2.2291e-04
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 6.5288e-04 - val_loss: 2.0356e-04
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 6.3141e-04 - val_loss: 1.9218e-04
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 6.1419e-04 - val_loss: 1.8097e-04
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 5.9693e-04 - val_loss: 1.7049e-04
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 5.7805e-04 - val_loss: 1.6173e-04
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 5.6020e-04 - val_loss: 1.5400e-04
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 5.4333e-04 - val_loss: 1.4719e-04
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 5.2732e-04 - val_loss: 1.4126e-04
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 5.1245e-04 - val_loss: 1.3612e-04
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 4.9880e-04 - val_loss: 1.3169e-04
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.8636e-04 - val_loss: 1.2790e-04
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.7514e-04 - val_loss: 1.2467e-04
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.6510e-04 - val_loss: 1.2195e-04
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 4.5618e-04 - val_loss: 1.1968e-04
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 4.4831e-04 - val_loss: 1.1781e-04
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 4.4143e-04 - val_loss: 1.1631e-04
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.3546e-04 - val_loss: 1.1515e-04
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 4.3032e-04 - val_loss: 1.1428e-04
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 4.2593e-04 - val_loss: 1.1369e-04
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.2221e-04 - val_loss: 1.1334e-04
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 4.1908e-04 - val_loss: 1.1321e-04
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.1648e-04 - val_loss: 1.1325e-04
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.1433e-04 - val_loss: 1.1344e-04
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.1256e-04 - val_loss: 1.1374e-04
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 4.1112e-04 - val_loss: 1.1413e-04
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 4.0994e-04 - val_loss: 1.1457e-04
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 4.0899e-04 - val_loss: 1.1504e-04
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 4.0821e-04 - val_loss: 1.1553e-04
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 4.0757e-04 - val_loss: 1.1602e-04
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 4.0703e-04 - val_loss: 1.1649e-04
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 4.0657e-04 - val_loss: 1.1693e-04
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 4.0617e-04 - val_loss: 1.1735e-04
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.0581e-04 - val_loss: 1.1774e-04
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 4.0548e-04 - val_loss: 1.1810e-04
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 4.0516e-04 - val_loss: 1.1842e-04
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 4.0484e-04 - val_loss: 1.1872e-04
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.0453e-04 - val_loss: 1.1899e-04
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 4.0422e-04 - val_loss: 1.1923e-04
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.0390e-04 - val_loss: 1.1945e-04
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.0357e-04 - val_loss: 1.1966e-04
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.0323e-04 - val_loss: 1.1984e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.0289e-04 - val_loss: 1.2002e-04
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 4.0253e-04 - val_loss: 1.2018e-04
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 4.0217e-04 - val_loss: 1.2033e-04
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 4.0179e-04 - val_loss: 1.2048e-04
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 4.0140e-04 - val_loss: 1.2062e-04
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.0100e-04 - val_loss: 1.2075e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 4.0060e-04 - val_loss: 1.2088e-04
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 4.0019e-04 - val_loss: 1.2100e-04
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 3.9977e-04 - val_loss: 1.2113e-04
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 3.9934e-04 - val_loss: 1.2125e-04
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 3.9891e-04 - val_loss: 1.2137e-04
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 3.9847e-04 - val_loss: 1.2148e-04
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 3.9803e-04 - val_loss: 1.2160e-04
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 3.9759e-04 - val_loss: 1.2172e-04
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 3.9714e-04 - val_loss: 1.2184e-04
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 3.9669e-04 - val_loss: 1.2196e-04
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 3.9624e-04 - val_loss: 1.2208e-04
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 3.9580e-04 - val_loss: 1.2220e-04
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 3.9535e-04 - val_loss: 1.2232e-04
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.9490e-04 - val_loss: 1.2245e-04
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 3.9445e-04 - val_loss: 1.2258e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 3.9401e-04 - val_loss: 1.2270e-04
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 3.9357e-04 - val_loss: 1.2284e-04
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 3.9314e-04 - val_loss: 1.2297e-04
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 3.9271e-04 - val_loss: 1.2311e-04
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 121ms/step - loss: 3.9229e-04 - val_loss: 1.2325e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 3.9188e-04 - val_loss: 1.2339e-04
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 3.9147e-04 - val_loss: 1.2354e-04
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 3.9108e-04 - val_loss: 1.2369e-04
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 3.9069e-04 - val_loss: 1.2385e-04
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 3.9031e-04 - val_loss: 1.2401e-04
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 3.8995e-04 - val_loss: 1.2417e-04
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 3.8960e-04 - val_loss: 1.2434e-04
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 3.8926e-04 - val_loss: 1.2452e-04
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 3.8894e-04 - val_loss: 1.2470e-04
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 3.8863e-04 - val_loss: 1.2489e-04
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 3.8833e-04 - val_loss: 1.2508e-04
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 3.8806e-04 - val_loss: 1.2527e-04
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 3.8780e-04 - val_loss: 1.2547e-04
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 3.8756e-04 - val_loss: 1.2568e-04
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 3.8734e-04 - val_loss: 1.2589e-04
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 3.8714e-04 - val_loss: 1.2611e-04
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 3.8697e-04 - val_loss: 1.2634e-04
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 3.8682e-04 - val_loss: 1.2656e-04
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 3.8669e-04 - val_loss: 1.2680e-04
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 3.8659e-04 - val_loss: 1.2703e-04
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 3.8652e-04 - val_loss: 1.2727e-04
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 3.8648e-04 - val_loss: 1.2752e-04
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 3.8647e-04 - val_loss: 1.2776e-04
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 3.8649e-04 - val_loss: 1.2800e-04
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 3.8655e-04 - val_loss: 1.2824e-04
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 14s 105ms/step - loss: 0.0276 - val_loss: 5.1116e-04
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0014 - val_loss: 5.7162e-04
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 9.6203e-04 - val_loss: 6.3487e-04
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 8.6400e-04 - val_loss: 4.6376e-04
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 7.7925e-04 - val_loss: 3.0051e-04
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 7.2401e-04 - val_loss: 2.4838e-04
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 6.6880e-04 - val_loss: 2.2487e-04
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 6.3907e-04 - val_loss: 2.1259e-04
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 6.3037e-04 - val_loss: 2.0271e-04
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - loss: 6.2079e-04 - val_loss: 1.9232e-04
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 6.0528e-04 - val_loss: 1.8303e-04
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 5.8844e-04 - val_loss: 1.7476e-04
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 5.7220e-04 - val_loss: 1.6723e-04
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 5.5649e-04 - val_loss: 1.6039e-04
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - loss: 5.4154e-04 - val_loss: 1.5424e-04
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 5.2760e-04 - val_loss: 1.4876e-04
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - loss: 5.1472e-04 - val_loss: 1.4394e-04
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 5.0294e-04 - val_loss: 1.3973e-04
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 4.9226e-04 - val_loss: 1.3609e-04
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 4.8267e-04 - val_loss: 1.3292e-04
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 4.7413e-04 - val_loss: 1.3015e-04
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 4.6661e-04 - val_loss: 1.2771e-04
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 4.6003e-04 - val_loss: 1.2556e-04
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 4.5432e-04 - val_loss: 1.2365e-04
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 4.4941e-04 - val_loss: 1.2198e-04
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 4.4520e-04 - val_loss: 1.2053e-04
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 4.4161e-04 - val_loss: 1.1929e-04
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 4.3856e-04 - val_loss: 1.1826e-04
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 4.3596e-04 - val_loss: 1.1741e-04
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 4.3374e-04 - val_loss: 1.1674e-04
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 4.3183e-04 - val_loss: 1.1623e-04
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 4.3017e-04 - val_loss: 1.1584e-04
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 4.2870e-04 - val_loss: 1.1555e-04
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 4.2739e-04 - val_loss: 1.1534e-04
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.2619e-04 - val_loss: 1.1520e-04
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 4.2508e-04 - val_loss: 1.1510e-04
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - loss: 4.2404e-04 - val_loss: 1.1503e-04
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 4.2304e-04 - val_loss: 1.1497e-04
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 4.2208e-04 - val_loss: 1.1493e-04
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 4.2114e-04 - val_loss: 1.1488e-04
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.2022e-04 - val_loss: 1.1484e-04
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 4.1931e-04 - val_loss: 1.1479e-04
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 4.1841e-04 - val_loss: 1.1474e-04
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 4.1752e-04 - val_loss: 1.1467e-04
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 4.1663e-04 - val_loss: 1.1460e-04
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - loss: 4.1575e-04 - val_loss: 1.1453e-04
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - loss: 4.1488e-04 - val_loss: 1.1444e-04
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 4.1400e-04 - val_loss: 1.1435e-04
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 4.1313e-04 - val_loss: 1.1426e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - loss: 4.1227e-04 - val_loss: 1.1416e-04
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 4.1141e-04 - val_loss: 1.1406e-04
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 4.1056e-04 - val_loss: 1.1395e-04
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.0971e-04 - val_loss: 1.1385e-04
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 4.0886e-04 - val_loss: 1.1374e-04
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - loss: 4.0803e-04 - val_loss: 1.1363e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - loss: 4.0720e-04 - val_loss: 1.1352e-04
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 4.0638e-04 - val_loss: 1.1341e-04
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - loss: 4.0557e-04 - val_loss: 1.1331e-04
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 4.0477e-04 - val_loss: 1.1320e-04
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 4.0398e-04 - val_loss: 1.1310e-04
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 4.0320e-04 - val_loss: 1.1300e-04
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - loss: 4.0243e-04 - val_loss: 1.1290e-04
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - loss: 4.0167e-04 - val_loss: 1.1281e-04
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 4.0092e-04 - val_loss: 1.1271e-04
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - loss: 4.0018e-04 - val_loss: 1.1263e-04
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - loss: 3.9946e-04 - val_loss: 1.1254e-04
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - loss: 3.9875e-04 - val_loss: 1.1246e-04
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - loss: 3.9805e-04 - val_loss: 1.1238e-04
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 3.9736e-04 - val_loss: 1.1231e-04
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 3.9669e-04 - val_loss: 1.1224e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 3.9604e-04 - val_loss: 1.1218e-04
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - loss: 3.9540e-04 - val_loss: 1.1212e-04
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 3.9477e-04 - val_loss: 1.1206e-04
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 3.9416e-04 - val_loss: 1.1201e-04
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 3.9357e-04 - val_loss: 1.1197e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 3.9300e-04 - val_loss: 1.1194e-04
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - loss: 3.9244e-04 - val_loss: 1.1191e-04
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 3.9190e-04 - val_loss: 1.1188e-04
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 3.9138e-04 - val_loss: 1.1187e-04
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 3.9088e-04 - val_loss: 1.1186e-04
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - loss: 3.9040e-04 - val_loss: 1.1186e-04
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 3.8993e-04 - val_loss: 1.1186e-04
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 3.8950e-04 - val_loss: 1.1188e-04
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 109ms/step - loss: 3.8908e-04 - val_loss: 1.1190e-04
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - loss: 3.8869e-04 - val_loss: 1.1194e-04
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 3.8832e-04 - val_loss: 1.1199e-04
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 3.8797e-04 - val_loss: 1.1205e-04
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 3.8766e-04 - val_loss: 1.1214e-04
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 3.8738e-04 - val_loss: 1.1224e-04
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 3.8713e-04 - val_loss: 1.1238e-04
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 3.8693e-04 - val_loss: 1.1256e-04
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - loss: 3.8679e-04 - val_loss: 1.1278e-04
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 3.8671e-04 - val_loss: 1.1305e-04
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - loss: 3.8671e-04 - val_loss: 1.1337e-04
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 3.8680e-04 - val_loss: 1.1373e-04
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 3.8696e-04 - val_loss: 1.1410e-04
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 3.8721e-04 - val_loss: 1.1448e-04
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - loss: 3.8753e-04 - val_loss: 1.1486e-04
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - loss: 3.8791e-04 - val_loss: 1.1521e-04
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - loss: 3.8835e-04 - val_loss: 1.1552e-04
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - loss: 0.0258 - val_loss: 8.9090e-04
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 0.0022 - val_loss: 8.7866e-04
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - loss: 0.0014 - val_loss: 5.7069e-04
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - loss: 0.0012 - val_loss: 5.1779e-04
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 0.0011 - val_loss: 4.2711e-04
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - loss: 9.5369e-04 - val_loss: 3.6468e-04
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 8.6245e-04 - val_loss: 3.3142e-04
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - loss: 7.8964e-04 - val_loss: 3.2800e-04
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 7.3936e-04 - val_loss: 3.4674e-04
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - loss: 7.2537e-04 - val_loss: 3.5188e-04
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 7.4766e-04 - val_loss: 3.1406e-04
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 7.6746e-04 - val_loss: 2.6852e-04
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 7.4680e-04 - val_loss: 2.4785e-04
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 7.1454e-04 - val_loss: 2.3770e-04
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 6.9480e-04 - val_loss: 2.2861e-04
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 6.7871e-04 - val_loss: 2.1911e-04
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 6.6179e-04 - val_loss: 2.0961e-04
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 6.4413e-04 - val_loss: 2.0031e-04
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - loss: 6.2616e-04 - val_loss: 1.9139e-04
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 6.0803e-04 - val_loss: 1.8307e-04
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 5.9000e-04 - val_loss: 1.7556e-04
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 5.7235e-04 - val_loss: 1.6903e-04
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 5.5538e-04 - val_loss: 1.6350e-04
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 5.3933e-04 - val_loss: 1.5894e-04
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 5.2439e-04 - val_loss: 1.5520e-04
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 5.1067e-04 - val_loss: 1.5208e-04
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.9824e-04 - val_loss: 1.4938e-04
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.8710e-04 - val_loss: 1.4688e-04
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 4.7721e-04 - val_loss: 1.4444e-04
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.6852e-04 - val_loss: 1.4194e-04
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 4.6094e-04 - val_loss: 1.3934e-04
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 4.5439e-04 - val_loss: 1.3666e-04
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 4.4878e-04 - val_loss: 1.3397e-04
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 4.4401e-04 - val_loss: 1.3134e-04
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.3998e-04 - val_loss: 1.2885e-04
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - loss: 4.3661e-04 - val_loss: 1.2658e-04
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 4.3379e-04 - val_loss: 1.2455e-04
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 4.3143e-04 - val_loss: 1.2280e-04
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.2944e-04 - val_loss: 1.2131e-04
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 4.2774e-04 - val_loss: 1.2006e-04
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 4.2627e-04 - val_loss: 1.1903e-04
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 4.2497e-04 - val_loss: 1.1819e-04
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 4.2379e-04 - val_loss: 1.1750e-04
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.2270e-04 - val_loss: 1.1693e-04
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.2167e-04 - val_loss: 1.1645e-04
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 4.2069e-04 - val_loss: 1.1606e-04
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 4.1974e-04 - val_loss: 1.1572e-04
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.1881e-04 - val_loss: 1.1543e-04
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.1790e-04 - val_loss: 1.1518e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.1701e-04 - val_loss: 1.1495e-04
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 4.1612e-04 - val_loss: 1.1475e-04
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 4.1525e-04 - val_loss: 1.1456e-04
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.1438e-04 - val_loss: 1.1439e-04
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 4.1352e-04 - val_loss: 1.1423e-04
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 4.1266e-04 - val_loss: 1.1408e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 4.1182e-04 - val_loss: 1.1394e-04
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 4.1097e-04 - val_loss: 1.1381e-04
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.1014e-04 - val_loss: 1.1369e-04
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.0931e-04 - val_loss: 1.1357e-04
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 4.0848e-04 - val_loss: 1.1346e-04
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 4.0767e-04 - val_loss: 1.1335e-04
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 4.0687e-04 - val_loss: 1.1325e-04
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 4.0608e-04 - val_loss: 1.1314e-04
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 4.0530e-04 - val_loss: 1.1303e-04
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 4.0454e-04 - val_loss: 1.1291e-04
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 4.0378e-04 - val_loss: 1.1279e-04
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.0302e-04 - val_loss: 1.1266e-04
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 4.0226e-04 - val_loss: 1.1252e-04
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 4.0150e-04 - val_loss: 1.1239e-04
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.0074e-04 - val_loss: 1.1226e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 3.9997e-04 - val_loss: 1.1212e-04
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 3.9922e-04 - val_loss: 1.1200e-04
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 3.9847e-04 - val_loss: 1.1188e-04
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 3.9773e-04 - val_loss: 1.1176e-04
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 3.9700e-04 - val_loss: 1.1165e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 3.9629e-04 - val_loss: 1.1154e-04
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 3.9560e-04 - val_loss: 1.1144e-04
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 3.9492e-04 - val_loss: 1.1135e-04
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 3.9427e-04 - val_loss: 1.1126e-04
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 3.9363e-04 - val_loss: 1.1118e-04
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 3.9302e-04 - val_loss: 1.1111e-04
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 3.9242e-04 - val_loss: 1.1104e-04
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 3.9185e-04 - val_loss: 1.1099e-04
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 3.9130e-04 - val_loss: 1.1094e-04
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 3.9078e-04 - val_loss: 1.1090e-04
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 3.9028e-04 - val_loss: 1.1086e-04
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 3.8980e-04 - val_loss: 1.1084e-04
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 3.8935e-04 - val_loss: 1.1082e-04
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 3.8893e-04 - val_loss: 1.1081e-04
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - loss: 3.8854e-04 - val_loss: 1.1081e-04
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 3.8817e-04 - val_loss: 1.1082e-04
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 3.8783e-04 - val_loss: 1.1083e-04
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 3.8752e-04 - val_loss: 1.1086e-04
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 3.8725e-04 - val_loss: 1.1089e-04
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 3.8701e-04 - val_loss: 1.1092e-04
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 3.8680e-04 - val_loss: 1.1097e-04
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 3.8663e-04 - val_loss: 1.1102e-04
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 3.8650e-04 - val_loss: 1.1107e-04
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 3.8641e-04 - val_loss: 1.1113e-04
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 3.8637e-04 - val_loss: 1.1120e-04
# LSTM-GRU Test loss: 0.00012823996075894684
# GRU-BiLSTM Test loss: 0.00011552067007869482
# LSTM-BiLSTM Test loss: 0.00011119728878838941
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# LSTM-GRU MSE: 0.0001352293882273812, MAE: 0.008311365168865027
# GRU-BiLSTM MSE: 0.00012551138680408054, MAE: 0.007749003519621332
# LSTM-BiLSTM MSE: 0.0001208772530254817, MAE: 0.007411173312374738
# LSTM-GRU RMSE: 0.012, MAPE: 2.11%
# GRU-BiLSTM RMSE: 0.011, MAPE: 1.99%
# LSTM-BiLSTM RMSE: 0.011, MAPE: 1.90%
# C:\Users\stumpa42\AppData\Loca\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - loss: 0.0140 - val_loss: 3.7644e-04
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 0.0012 - val_loss: 3.4390e-04
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 9.8486e-04 - val_loss: 2.2817e-04
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 8.6134e-04 - val_loss: 2.2279e-04
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 7.6082e-04 - val_loss: 1.5296e-04
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 7.0512e-04 - val_loss: 1.4113e-04
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 6.6133e-04 - val_loss: 1.3485e-04
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 6.2060e-04 - val_loss: 1.2886e-04
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 5.8641e-04 - val_loss: 1.2298e-04
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 5.5848e-04 - val_loss: 1.1777e-04
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 5.3548e-04 - val_loss: 1.1325e-04
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 5.1607e-04 - val_loss: 1.0929e-04
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.9953e-04 - val_loss: 1.0575e-04
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 4.8555e-04 - val_loss: 1.0260e-04
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.7401e-04 - val_loss: 9.9812e-05
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.6481e-04 - val_loss: 9.7381e-05
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.5770e-04 - val_loss: 9.5318e-05
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 4.5231e-04 - val_loss: 9.3622e-05
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.4820e-04 - val_loss: 9.2274e-05
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.4498e-04 - val_loss: 9.1239e-05
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 4.4233e-04 - val_loss: 9.0473e-05
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 4.4006e-04 - val_loss: 8.9924e-05
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 4.3805e-04 - val_loss: 8.9546e-05
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.3623e-04 - val_loss: 8.9296e-05
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 4.3455e-04 - val_loss: 8.9141e-05
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 4.3299e-04 - val_loss: 8.9056e-05
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 4.3153e-04 - val_loss: 8.9019e-05
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.3016e-04 - val_loss: 8.9017e-05
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.2887e-04 - val_loss: 8.9040e-05
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 4.2765e-04 - val_loss: 8.9081e-05
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 4.2649e-04 - val_loss: 8.9134e-05
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.2538e-04 - val_loss: 8.9196e-05
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 4.2433e-04 - val_loss: 8.9264e-05
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 4.2333e-04 - val_loss: 8.9338e-05
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 4.2237e-04 - val_loss: 8.9415e-05
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.2145e-04 - val_loss: 8.9495e-05
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 4.2057e-04 - val_loss: 8.9578e-05
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.1972e-04 - val_loss: 8.9663e-05
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 4.1891e-04 - val_loss: 8.9749e-05
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 4.1812e-04 - val_loss: 8.9839e-05
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 4.1737e-04 - val_loss: 8.9929e-05
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 4.1664e-04 - val_loss: 9.0021e-05
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 4.1594e-04 - val_loss: 9.0115e-05
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 4.1526e-04 - val_loss: 9.0210e-05
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.1460e-04 - val_loss: 9.0307e-05
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.1397e-04 - val_loss: 9.0406e-05
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 4.1335e-04 - val_loss: 9.0506e-05
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 4.1276e-04 - val_loss: 9.0608e-05
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 4.1218e-04 - val_loss: 9.0711e-05
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 4.1162e-04 - val_loss: 9.0817e-05
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.1108e-04 - val_loss: 9.0924e-05
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 4.1055e-04 - val_loss: 9.1034e-05
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.1003e-04 - val_loss: 9.1145e-05
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.0953e-04 - val_loss: 9.1258e-05
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.0905e-04 - val_loss: 9.1374e-05
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.0857e-04 - val_loss: 9.1492e-05
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 4.0811e-04 - val_loss: 9.1611e-05
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.0766e-04 - val_loss: 9.1734e-05
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 4.0722e-04 - val_loss: 9.1860e-05
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 4.0680e-04 - val_loss: 9.1988e-05
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.0639e-04 - val_loss: 9.2120e-05
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.0599e-04 - val_loss: 9.2254e-05
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 4.0560e-04 - val_loss: 9.2393e-05
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 4.0522e-04 - val_loss: 9.2535e-05
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.0486e-04 - val_loss: 9.2681e-05
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 4.0451e-04 - val_loss: 9.2832e-05
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 4.0418e-04 - val_loss: 9.2986e-05
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 4.0385e-04 - val_loss: 9.3146e-05
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 4.0355e-04 - val_loss: 9.3311e-05
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 4.0326e-04 - val_loss: 9.3480e-05
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 4.0299e-04 - val_loss: 9.3655e-05
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 4.0274e-04 - val_loss: 9.3835e-05
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 4.0251e-04 - val_loss: 9.4021e-05
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.0230e-04 - val_loss: 9.4213e-05
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.0211e-04 - val_loss: 9.4410e-05
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 4.0195e-04 - val_loss: 9.4614e-05
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 4.0182e-04 - val_loss: 9.4823e-05
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.0172e-04 - val_loss: 9.5037e-05
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 4.0165e-04 - val_loss: 9.5256e-05
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.0162e-04 - val_loss: 9.5481e-05
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 4.0163e-04 - val_loss: 9.5707e-05
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 4.0169e-04 - val_loss: 9.5936e-05
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.0180e-04 - val_loss: 9.6164e-05
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.0197e-04 - val_loss: 9.6389e-05
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.0220e-04 - val_loss: 9.6607e-05
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.0251e-04 - val_loss: 9.6811e-05
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.0290e-04 - val_loss: 9.6993e-05
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 4.0340e-04 - val_loss: 9.7145e-05
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.0400e-04 - val_loss: 9.7249e-05
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.0473e-04 - val_loss: 9.7287e-05
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 4.0559e-04 - val_loss: 9.7234e-05
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.0661e-04 - val_loss: 9.7056e-05
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 4.0779e-04 - val_loss: 9.6714e-05
# Epoch 94/100
# ...
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.7352e-04 - val_loss: 9.9744e-05
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 4.6132e-04 - val_loss: 9.8290e-05
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 4.4403e-04 - val_loss: 8.1203e-05
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 4.5531e-04 - val_loss: 9.5554e-05
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 4.3876e-04 - val_loss: 1.1047e-04
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 4.2893e-04 - val_loss: 8.3571e-05
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 4.2539e-04 - val_loss: 1.0350e-04
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 4.2339e-04 - val_loss: 8.6351e-05
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 4.1929e-04 - val_loss: 9.8055e-05
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 4.1447e-04 - val_loss: 9.3126e-05
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.1222e-04 - val_loss: 9.7201e-05
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 4.1220e-04 - val_loss: 9.3326e-05
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 4.0936e-04 - val_loss: 9.5955e-05
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 4.0985e-04 - val_loss: 9.2961e-05
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 4.0828e-04 - val_loss: 9.5069e-05
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 4.8696e-04 - val_loss: 1.0131e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 5.1371e-04 - val_loss: 6.3987e-05
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 4.8647e-04 - val_loss: 9.0007e-05
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 4.1977e-04 - val_loss: 7.9872e-05
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 4.1465e-04 - val_loss: 8.5515e-05
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 4.1291e-04 - val_loss: 7.9916e-05
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 4.1370e-04 - val_loss: 9.2279e-05
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 4.1148e-04 - val_loss: 7.9279e-05
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 4.1323e-04 - val_loss: 9.6341e-05
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 4.1157e-04 - val_loss: 7.9487e-05
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 4.1234e-04 - val_loss: 9.8284e-05
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 4.1089e-04 - val_loss: 8.0366e-05
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 4.1075e-04 - val_loss: 9.8716e-05
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 4.0906e-04 - val_loss: 8.1717e-05
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 4.0865e-04 - val_loss: 9.7430e-05
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 4.0657e-04 - val_loss: 8.3259e-05
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 4.0641e-04 - val_loss: 9.4942e-05
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 4.0421e-04 - val_loss: 8.4675e-05
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 4.0411e-04 - val_loss: 9.2517e-05
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 4.0204e-04 - val_loss: 8.5893e-05
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 4.0158e-04 - val_loss: 9.0757e-05
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 3.9969e-04 - val_loss: 8.6979e-05
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 3.9866e-04 - val_loss: 8.9812e-05
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 3.9683e-04 - val_loss: 8.8046e-05
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 3.9521e-04 - val_loss: 8.9681e-05
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 3.9332e-04 - val_loss: 8.9127e-05
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 3.9137e-04 - val_loss: 9.0016e-05
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 3.8958e-04 - val_loss: 8.9763e-05
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 3.8766e-04 - val_loss: 8.9922e-05
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 3.8584e-04 - val_loss: 8.9478e-05
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 3.8379e-04 - val_loss: 8.9218e-05
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 3.8177e-04 - val_loss: 8.8817e-05
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 3.7958e-04 - val_loss: 8.8637e-05
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 3.7742e-04 - val_loss: 8.8459e-05
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 3.7529e-04 - val_loss: 8.8162e-05
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 3.7339e-04 - val_loss: 8.7516e-05
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 3.7174e-04 - val_loss: 8.6752e-05
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 3.7033e-04 - val_loss: 8.6052e-05
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 3.6916e-04 - val_loss: 8.5315e-05
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 3.6840e-04 - val_loss: 8.4197e-05
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 3.6810e-04 - val_loss: 8.2635e-05
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 3.6787e-04 - val_loss: 8.1412e-05
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 3.6762e-04 - val_loss: 8.0572e-05
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 3.6737e-04 - val_loss: 7.9932e-05
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 3.6711e-04 - val_loss: 7.9351e-05
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 3.6682e-04 - val_loss: 7.8821e-05
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - loss: 0.0116 - val_loss: 2.9122e-04
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 0.0017 - val_loss: 2.6806e-04
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0013 - val_loss: 1.8613e-04
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0012 - val_loss: 1.6766e-04
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0011 - val_loss: 1.5967e-04
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.0010 - val_loss: 1.4761e-04
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 9.4059e-04 - val_loss: 1.4083e-04
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 9.1225e-04 - val_loss: 1.3711e-04
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 8.9786e-04 - val_loss: 1.3475e-04
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 8.8403e-04 - val_loss: 1.3332e-04
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 8.7158e-04 - val_loss: 1.3246e-04
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 8.6043e-04 - val_loss: 1.3187e-04
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 8.5029e-04 - val_loss: 1.3127e-04
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 8.4085e-04 - val_loss: 1.3039e-04
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 8.3164e-04 - val_loss: 1.2896e-04
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 8.2209e-04 - val_loss: 1.2676e-04
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 8.1154e-04 - val_loss: 1.2369e-04
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 7.9927e-04 - val_loss: 1.1979e-04
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 7.8470e-04 - val_loss: 1.1525e-04
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 7.6746e-04 - val_loss: 1.1038e-04
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 7.4759e-04 - val_loss: 1.0559e-04
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 7.2548e-04 - val_loss: 1.0123e-04
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 7.0190e-04 - val_loss: 9.7580e-05
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 6.7791e-04 - val_loss: 9.4823e-05
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 6.5469e-04 - val_loss: 9.3025e-05
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 6.3344e-04 - val_loss: 9.2180e-05
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 6.1512e-04 - val_loss: 9.2239e-05
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 6.0015e-04 - val_loss: 9.3092e-05
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 5.8815e-04 - val_loss: 9.4496e-05
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 5.7834e-04 - val_loss: 9.5592e-05
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 5.7171e-04 - val_loss: 9.3497e-05
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 5.6648e-04 - val_loss: 1.0460e-04
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 5.3637e-04 - val_loss: 1.0564e-04
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 5.3766e-04 - val_loss: 1.0925e-04
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 5.2837e-04 - val_loss: 1.1347e-04
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 5.2231e-04 - val_loss: 1.1763e-04
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 5.1700e-04 - val_loss: 1.2191e-04
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 5.1214e-04 - val_loss: 1.2666e-04
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 5.0733e-04 - val_loss: 1.3163e-04
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 5.0309e-04 - val_loss: 1.3669e-04
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.9936e-04 - val_loss: 1.4195e-04
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.9587e-04 - val_loss: 1.4749e-04
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 4.9265e-04 - val_loss: 1.5315e-04
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 4.8976e-04 - val_loss: 1.5885e-04
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 4.8710e-04 - val_loss: 1.6455e-04
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.8468e-04 - val_loss: 1.7008e-04
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.8249e-04 - val_loss: 1.7542e-04
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.8048e-04 - val_loss: 1.8050e-04
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 4.7864e-04 - val_loss: 1.8534e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 4.7697e-04 - val_loss: 1.8989e-04
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.7543e-04 - val_loss: 1.9423e-04
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.7404e-04 - val_loss: 1.9815e-04
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.7272e-04 - val_loss: 2.0201e-04
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 4.7161e-04 - val_loss: 2.0487e-04
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 4.7031e-04 - val_loss: 2.0866e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.6969e-04 - val_loss: 2.0862e-04
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.6771e-04 - val_loss: 2.1412e-04
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.6865e-04 - val_loss: 2.0177e-04
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 4.6468e-04 - val_loss: 2.1247e-04
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.6667e-04 - val_loss: 1.5109e-04
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 5.0504e-04 - val_loss: 1.4598e-04
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.7548e-04 - val_loss: 1.7730e-04
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.5630e-04 - val_loss: 2.1786e-04
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.6434e-04 - val_loss: 2.0533e-04
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.6240e-04 - val_loss: 2.0989e-04
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.6171e-04 - val_loss: 2.2105e-04
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.6087e-04 - val_loss: 2.1014e-04
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 4.6181e-04 - val_loss: 2.0920e-04
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.5836e-04 - val_loss: 2.0491e-04
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.5997e-04 - val_loss: 2.0186e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.5656e-04 - val_loss: 1.9801e-04
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 4.5738e-04 - val_loss: 1.9250e-04
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.5367e-04 - val_loss: 1.8302e-04
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 4.5202e-04 - val_loss: 1.7223e-04
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.4716e-04 - val_loss: 1.6744e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.4601e-04 - val_loss: 1.7615e-04
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.4854e-04 - val_loss: 1.8188e-04
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.4722e-04 - val_loss: 1.7935e-04
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.4706e-04 - val_loss: 1.6562e-04
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.4392e-04 - val_loss: 1.5319e-04
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.3907e-04 - val_loss: 1.4994e-04
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.3837e-04 - val_loss: 1.5554e-04
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 4.3993e-04 - val_loss: 1.5664e-04
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.3905e-04 - val_loss: 1.5211e-04
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.3689e-04 - val_loss: 1.4642e-04
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 4.3465e-04 - val_loss: 1.4083e-04
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.3199e-04 - val_loss: 1.3748e-04
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.3005e-04 - val_loss: 1.3702e-04
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.2914e-04 - val_loss: 1.3725e-04
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.2848e-04 - val_loss: 1.3600e-04
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.2728e-04 - val_loss: 1.3347e-04
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.2559e-04 - val_loss: 1.3073e-04
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.2382e-04 - val_loss: 1.2850e-04
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.2227e-04 - val_loss: 1.2749e-04
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.2109e-04 - val_loss: 1.2760e-04
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.2040e-04 - val_loss: 1.2693e-04
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.1975e-04 - val_loss: 1.2450e-04
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 4.1810e-04 - val_loss: 1.2280e-04
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.1638e-04 - val_loss: 1.2157e-04
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.1572e-04 - val_loss: 1.2149e-04
# LSTM-GRU Test loss: 7.365225610556081e-05
# GRU-BiLSTM Test loss: 7.882092177169397e-05
# LSTM-BiLSTM Test loss: 0.0001214916628669016
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# LSTM-GRU MSE: 7.894799542834805e-05, MAE: 0.006258469003857049
# GRU-BiLSTM MSE: 8.445686486094392e-05, MAE: 0.006363754424353857
# LSTM-BiLSTM MSE: 0.00012489427292000332, MAE: 0.008955157418364333
# LSTM-GRU RMSE: 0.009, MAPE: 4.50%
# GRU-BiLSTM RMSE: 0.009, MAPE: 4.45%
# LSTM-BiLSTM RMSE: 0.011, MAPE: 6.57%
